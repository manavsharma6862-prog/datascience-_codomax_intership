# %% [markdown]
# # DATASCIENCE INTERSHIP - DAY 1
# # ENVIRONMENT SETUP
# # "NAME" - "MANAV SHARMA"
# # Intership :datascience
# # company - codomax digital solution
# # task -- environment setup

# %%
print("Hello, Data Science!")
print("My name is Manav Sharma")
print("Welcome to Day 1")
# Out:
# Hello, Data Science!
# My name is Manav Sharma
# Welcome to Day 1
