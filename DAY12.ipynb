# %% [markdown]
# # DataScience intership Day 12
# # Name -- Manav Sharma
# #  Company -- codomax digital solution
# # task -- Project Improvement

# %%
#Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("students.csv")

# Display first five rows
df.head()

# %%
#Display Dataset Information

# Dataset information

print("Dataset Information")
df.info()

print("\nStatistical Summary")
print(df.describe())

# %%
#Clean the Dataset

# Remove duplicate records
df = df.drop_duplicates()

# Remove missing values
df = df.dropna()

print("Dataset cleaned successfully!")

# %%
#Perform Data Analysis
print("Total Students :", df["Name"].count())
print("Average Marks  :", df["Marks"].mean())
print("Highest Marks  :", df["Marks"].max())
print("Lowest Marks   :", df["Marks"].min())

# %%
# bar chart 
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("students.csv")

# Display first few rows
print(df.head())

# Check column names
print(df.columns)

# Convert Marks to numeric (if needed)
df["Marks"] = pd.to_numeric(df["Marks"], errors="coerce")

# Remove rows with missing marks
df = df.dropna(subset=["Marks"])

# Create Bar Chart
plt.figure(figsize=(8,5))
plt.bar(df["Name"], df["Marks"])

plt.title("Student Marks Comparison")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.grid(axis="y")
plt.show()
# Out:
#     Name  Age Course  Marks
# 0  Manav   21    BCA     88
# 1  Rahul   22    MCA     91
# 2  Priya   20    BSc     85
# 3   Aman   23    BCA     79
# 4   Neha   21    MCA     95
# Index(['Name', 'Age', 'Course', 'Marks'], dtype='object')

# %%
#Export Cleaned Dataset
df.to_csv("final_cleaned_students.csv", index=False)

print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!
