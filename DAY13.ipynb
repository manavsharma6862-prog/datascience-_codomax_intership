# %% [markdown]
# # Day 13 – GitHub Project Upload
#
# ## Objective
# Upload the complete Data Science Internship project to GitHub.
#
# ## Files Uploaded
# - Day 1–13 Jupyter Notebooks
# - students.csv
# - cleaned_students.csv
# - Charts
# - README.md
#
# ## Outcome
# The complete project is successfully available on GitHub.

# %%
print("Day 13 - GitHub Project Upload")
print("Project uploaded successfully.")
# Out:
# Day 13 - GitHub Project Upload
# Project uploaded successfully.

# %%
import os

files = os.listdir()

print("Project Files:")
for file in files:
    print(file)

# %%
github_repo = "https://github.com/manavsharma6862-prog/datascience-_codomax_intership"

print("GitHub Repository:")
print(github_repo)
# Out:
# GitHub Repository:
# https://github.com/manavsharma6862-prog/datascience-_codomax_intership

# %% [markdown]
# ## Conclusion
#
# The complete internship project has been organized and uploaded to GitHub.
#
# Skills Demonstrated:
# - Git
# - GitHub
# - Repository Management
# - Project Documentation
# - Version Control
