# %% [markdown]
# # DataScience intership Day 14
# # Name -- Manav Sharma
# #  Company -- codomax digital solution
# # task -- Submit the completed Data Science Internship project.

# %% [markdown]
# # Day 14 – Final Project Submission
#
# ## Objective
# Submit the completed Data Science Internship project.
#
# ## Submitted Files
# - Day 1–14 Jupyter Notebooks
# - students.csv
# - cleaned_students.csv
# - final_cleaned_students.csv
# - Charts
# - README.md
# - GitHub Repository
# - Demo Video
#
# ## Expected Outcome
# The complete project has been successfully submitted through the Google Form.
