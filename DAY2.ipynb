# %%
#variables

# %%
name = "manav sharma"
age = 24 
course = "python programming"

print ("my name is " + name + " and my age is " + str(age) + " and i am learning " + course)
# Out:
# my name is manav sharma and my age is 24 and i am learning python programming

# %%
# loops 
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# functions
def greet(name):
    print("Hello, " + name + "!")
