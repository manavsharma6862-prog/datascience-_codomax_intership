# %% [markdown]
# # DATASCIENCE INTERSHIP - DAY 6
# # "NAME" - "MANAV SHARMA"
# # Intership :datascience
# # company - codomax digital solution
# # task -- panads filteration

# %%
#Load the Dataset
import pandas as pd

df = pd.read_csv("students.csv")

print(df)

# %%
#Display Selected Columns
import pandas as pd

df = pd.read_csv("students.csv")

print(df[["Name", "Marks"]])

# %%
#Filter Students with Marks Greater Than 80


df = pd.read_csv("students.csv")

filtered = df[df["Marks"] > 80]

print(filtered)

# %%
#Filter Multiple Conditions

df = pd.read_csv("students.csv")

result = df[(df["Course"] == "MCA") & (df["Marks"] > 90)]

print(result)

# %%
#Save the Filtered Dataset


df = pd.read_csv("students.csv")

filtered = df[df["Marks"] > 80]

filtered.to_csv("filtered_students.csv", index=False)

print("Filtered dataset saved successfully!")
